# %% [markdown]
# <a href="https://colab.research.google.com/github/cazaress123/fundamentos-/blob/main/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Variable1 = 70
Variable2 = 70
if Variable1 > Variable2:
  print(Variable1, "es mayor que", Variable2)
elif Variable1 == Variable2:
  print(Variable1, "es igual que", Variable2)
else:
  print(Variable2, "es mayor que", Variable1)
# Out:
# 70 es igual que 70

# %%
edad = int(input ("dame tu edad"))
if edad >= 65:
  print("eres un adulto mayor")
elif edad >= 30:
  print("eres un adulto")
elif edad >= 18:
  print("eres un adolecente")
elif edad >= 1:
  print("eres un niño")
# Out:
# dame tu edad20
# eres un adolecente

# %%
10 > 5 and 10 > 7 and 10 > 1
# Out:
# True

# %%
# Comparamos 3 condiciones y el operador and y todas deben cumplirse para que el resultado sea verdadero
10 > 5 and 10 > 7 and 10 > 11
# Out:
# False

# %%
10 > 5 or 10 > 7 or 10 > 11
# Out:
# True

# %%
edad = int(input ("dame tu edad"))
if edad >= 66:
  print("eres un adulto mayor")
elif edad >= 31 and edad <= 65:
  print("eres un adulto")
elif edad >= 18 and edad <= 30:
  print("eres un adulto joven")
elif edad >= 13 and edad <= 17:
  print("eres un adolecente")
elif edad >= 1 and edad <= 13:
  print("eres un niño")
# Out:
# dame tu edad12
# eres un niño

# %%
## Instrucción for sirve para repetir instrucciones
tabla = 7
for i in range(10):
  print(tabla, "*", i, "=", tabla*i)
# Out:
# 7 * 0 = 0
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63

# %%
tabla = 7
for i in range(10, 100, 5):
  print(tabla, "*", i, "=", tabla*i)
# Out:
# 7 * 10 = 70
# 7 * 15 = 105
# 7 * 20 = 140
# 7 * 25 = 175
# 7 * 30 = 210
# 7 * 35 = 245
# 7 * 40 = 280
# 7 * 45 = 315
# 7 * 50 = 350
# 7 * 55 = 385
# 7 * 60 = 420
# 7 * 65 = 455
# 7 * 70 = 490
# 7 * 75 = 525
# 7 * 80 = 560
# 7 * 85 = 595
# 7 * 90 = 630
# 7 * 95 = 665
