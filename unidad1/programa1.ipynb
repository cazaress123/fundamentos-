# %% [markdown]
# <a href="https://colab.research.google.com/github/cazaress123/fundamentos-/blob/main/unidad1/programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
variable1 = 70
variable2 = 70
if variable1 > variable2:
  print( variable1, "es mayor que", variable2 )
  else:
    print(variable2, "es mayor que", variable1)

# %%
edad = int(input("dame tu edad"))
if edad <=10:
  print ("eres un niño")
  elif edad <18:
    print ("eres un adolescente")
    else:
      print ("eres un adulto joven")
      elif edad <65:
        print ("eres un adulto")
        else:
          print ("eres un anciano")
#

# %%
edad = int(input("dame tu edad"))

if edad >= 65:
  print("eres un anciano")
elif edad >= 18:
  print("eres un adulto")
elif edad >= 10:
  print("eres un adolescente")
else:
  print("eres un niño")
# Out:
# dame tu edad13
# eres un adolescente
