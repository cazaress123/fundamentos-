# %% [markdown]
# <a href="https://colab.research.google.com/github/cazaress123/fundamentos-/blob/main/sistema%20de%20prestamos%20version%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 INGENIERIA EN SISTEMAS COMPUTACIONALES 1


FUNDAMENTOS DE PROGRAMACION

UNIDAD 1
Angel Ariel Cazares Serrano
Jose Gabriel

# %%
2. buscar por software
elif opcion == 2:
  programa = input("\\nIngrese el software que desea buscar:")
  print ("\\m --- RESULTADOS ---")
  encontrado = false
  for i in range (len(computadoras)):
    #la funcion (lower) convierte en minuscula el texto, de esta forma
    #nos aseguramos que el texto a buscar y la informacion de las listas
    #este en minuscula y no tengamos problema de que no encuentra un programa
    #porque este escrito de forma diferente usando mayusculas y minusculas
    if programa.lower () in software [i]. lower ():
      print ("ID",computadoras[i])
      print ("aula:", aulas [i])
      print ("software:", software [i])
      print ("estado:" , estados [i])
      encontrado = true
      if encontrado == false:
        print ("no se encontraron computadoras con ese software")

# %%
#=====================================
#SISTEMA DE PRESTAMOS
#Version 1 - Programacion basica y uso de listas
#=====================================

#Lista de alumnos activos en el sistema
alumnos = ["26040200", "26040201","26040202","26040203","26040204"]

#cada valor en la lista de computadoras tiene su lista correspondiente con el
#auña donde esta ubicada,el software instalado y el estado de la computadora
computadoras = ["PC-LC1-01","PC-LC1-02","PC-LC1-03"
                "PC-LC2-01","PC.LC2-02","PC-LC2-03"
                "PC-LC3-01","PC-LC3-02","PC-LC3-03"]
aulas = ["LC1","LC1","LC1"
        "LC2","LC2","LC2"
        "LC3","LC3","LC3","LC3"]
sofware = ["Python,VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB"
           "Python, VS Code", "Python, Java,VS Code","AutoCAD, MATLAB"]
           "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB","Python, VS Code"

# %%
estados = ["Disponible","Prestada","Reservada",]
#MENU PRINCIPAL
#Usamos un ciclo While que se repetira indefinidamente hasta que el usuario
#teclee la opcion 7 (salir o cualquier numero superior al 7)
opcion = 0
while opcion<= 6:
  print("\n====================================")
  print("           SISTEMA DE PRESTAMOS")
  print("=====================================")
  print("1. Consultar computadoras")
  print("2. Buscar por software")
  print("3. Solicitar prestamo")
  print("4. Devolver computadora")
  print("5. Reservar computadora")
  print("6. Agregar computadora")
  print("7. Salir")
  print("=====================================")
  opcion = int(input("Ingrese una opcion:"))

# %%
#Consultar computadoras
#si el usuario selecciono la opcion 1 se hace un ciclo (for)que recorre
#toda la lista de computadoras e imprime los valores de las demas listas
if opcion == 1:
  print("\n---COMPUTADORAS ---")
  for i in range (len(computadoras)):
    print("ID:",computadoras[i])
    print("aula:", aulas [i])
    print("software:", software [i])
    print("estado:" , estados [i])
    print("---------------------------")

# %%
#3. Solicitar prestamo
elif opcion ==3
print("\n---SOLICITAR PRESTAMO---")
num_control = Input ( "\nIngrese el numero de control")
encontrado1 = False
#Verificar si existe el alumno en la lista o BD
if num_control in alumnos:
  #Si existe, continuamos con el procedimiento
  encontrado1 = True
  id_computadora = input("Ingrese el ID de la computadora:")
  encontrado2 = False
  for i in range(len(computadoras)):
        if computadoras [i] == id_computadora:
          encoantrado2 =  True
          if estados [i] = "Disponible"
          estados [i] = "Prestada"
          print ("Prestamo registrado correctamente.")
          print ("Computadora:", computadoras [i])
          print ("Aula:",aulas [i])
          else:
            print("La computadora no esta disponible")
            if encontrado2 == False:
              print("La computadora no existe")
              if encontrado1 == False:
                print("El alumno no existe")

# %%
#Agregar computadora
elif opcion ==6:
  print("\n---AGREGAR COMPUTADORA---")
  id_computadora = input("Ingrese el ID de la computadora:")
  aula = input("aula:")
  software = input("software instalado:")
  computadoras.append(id_computadora)
  aulas.append(aula)
  software.append(software)
  estados.append("Disponible")
  print("Computadora agregada correctamente.")
